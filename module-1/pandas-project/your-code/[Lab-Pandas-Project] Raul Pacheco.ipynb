# %%
# Leer el archivo de ataques de tiburones
# Ubicar que columna necesita limpieza
# Cambiar el nombre a las columnas
# Eliminar filas sin informacion
# Modificar contenido de columnas
# Cambiar el formato de la hora
# Anadir 0 en el vacio de informacion
# Crear funcion en species para remover nan

import pandas as pd
import numpy as np
import hashlib
import re
from urllib.parse import urlparse

# %%
tabla = pd.read_csv('attacks.csv', encoding = 'latin1')
tabla.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
# dictionary like

tabla['Date']
# Out:
# 0        25-Jun-2018
# 1        18-Jun-2018
# 2        09-Jun-2018
# 3        08-Jun-2018
# 4        04-Jun-2018
#             ...
# 25718            NaN
# 25719            NaN
# 25720            NaN
# 25721            NaN
# 25722            NaN
# Name: Date, Length: 25723, dtype: object

# %%
tabla[['Area', 'Location']]
# Out:
#                   Area                        Location
# 0           California     Oceanside, San Diego County
# 1              Georgia  St. Simon Island, Glynn County
# 2               Hawaii                    Habush, Oahu
# 3      New South Wales              Arrawarra Headland
# 4               Colima                        La Ticla
# ...                ...                             ...
# 25718              NaN                             NaN
# 25719              NaN                             NaN
# 25720              NaN                             NaN
# 25721              NaN                             NaN
# 25722              NaN                             NaN
#
# [25723 rows x 2 columns]

# %%
# Numpy like

tabla.iloc[10:15]
# Out:
#      Case Number         Date    Year        Type    Country  \
# 10    2018.05.24  24-May-2018  2018.0    Provoked  AUSTRALIA
# 11    2018.05.21  21-May-2018  2018.0  Unprovoked        USA
# 12  2018.05.13.b  13-May-2018  2018.0  Unprovoked        USA
# 13  2018.05.13.a  13-May-2018  2018.0     Invalid    ENGLAND
# 14    2018.05.00     May 2018  2018.0    Provoked  AUSTRALIA
#
#                  Area                             Location         Activity  \
# 10         Queensland                      Cairns Aquarium   Feeding sharks
# 11     South Carolina    Isle of Palms,  Charleston County  Boogie boarding
# 12     South Carolina  Hilton Head Island, Beaufort County         Swimming
# 13           Cornwall                       Off Land's End          Fishing
# 14  Westerm Australia                           Dugong Bay   Feeding sharks
#
#                Name Sex   ...               Species   \
# 10             male    M  ...        Grey reef shark
# ...

# %%
tabla.iloc[13]['Date']
# Out:
# '13-May-2018'

# %%
tabla.iloc[:5,  0]
# Out:
# 0    2018.06.25
# 1    2018.06.18
# 2    2018.06.09
# 3    2018.06.08
# 4    2018.06.04
# Name: Case Number, dtype: object

# %%
tabla.loc[:, 'Type': 'Name' ]
# Out:
#              Type    Country             Area                        Location  \
# 0         Boating        USA       California     Oceanside, San Diego County
# 1      Unprovoked        USA          Georgia  St. Simon Island, Glynn County
# 2         Invalid        USA           Hawaii                    Habush, Oahu
# 3      Unprovoked  AUSTRALIA  New South Wales              Arrawarra Headland
# 4        Provoked     MEXICO           Colima                        La Ticla
# ...           ...        ...              ...                             ...
# 25718         NaN        NaN              NaN                             NaN
# 25719         NaN        NaN              NaN                             NaN
# 25720         NaN        NaN              NaN                             NaN
# 25721         NaN        NaN              NaN                             NaN
# 25722         NaN        NaN              NaN                             NaN
#
# ...

# %% [markdown]
# # Data wrangling

# %%
# 1. Anadir newspapar

# %%
# tabla['Columna'] = 'Tabla'

# %%
# Obtener el host

# tabla['host'] = tabla['href'].apply(lambda href: urlparse(href).netloc)

# %%
tabla['pdf'].value_counts()
# Out:
# 1931.09.21.a-b-Holaday-Barrows.pdf     2
# 1921.11.27.a-b-Jack.pdf                2
# 1906.09.27.R.a&b-Munich-Swede.pdf      2
# 1916.07.12.a-b-Stillwell-Fisher.pdf    2
# 1907.10.16.R-HongKong.pdf              2
#                                       ..
# 1902.06.00-Giorgos.pdf                 1
# 1975.04.05-Thompson.pdf                1
# 2000.10.20-Licamele.pdf                1
# 2016.04.13-Senkowicz.pdf               1
# 1963.12.21-Cook.pdf                    1
# Name: pdf, Length: 6291, dtype: int64

# %%
# 3. REllenar datos faltantes

#missing_titles_mask = tabla['Type'].isna()

#(tabla[missing_titles_mask]['href']
#   .str.extract(r'(?P<missing_type>[^/]+)$')
#   .applymap(lambda title: title.split('-'))
#   .applymap(lambda title_word_list: ' '.join(title_word_list))
#    )
#missing_titles_mask

# %%
#uids = (tabla
#           .apply(lambda row: hashlib.md5(bytes(row['href'].encode())), axis = 1)
#           .apply(lambda hash_object: hash_objetct.hexdigest())
#       )
#tabla['href'] = uids
#tabla.set_index['href', inplace = True]

#tabla

# %%
tabla.shape
# Out:
# (25723, 24)

# %%
tabla.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
tabla_clean=tabla.drop(columns=['Area'])
print (tabla.columns.shape)
print (tabla_clean.columns.shape)
print (type(tabla_clean.columns.shape))
# Out:
# (24,)
# (23,)
# <class 'tuple'>

# %%
null_cols=tabla_clean.isnull().sum()
null_cols[null_cols>0]
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
tabla.sum()
# Out:
# Year              12141816.0
# original order    19911202.0
# dtype: float64

# %%
type(tabla)
# Out:
# pandas.core.frame.DataFrame

# %%
tabla.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
tabla.Area.value_counts(sort='ascending')
# Out:
# Florida            1037
# New South Wales     486
# Queensland          311
# Hawaii              298
# California          290
#                    ...
# Anjouan               1
# Moala Island          1
# Jeju Province         1
# Taranto               1
# Conakry Region        1
# Name: Area, Length: 825, dtype: int64

# %%
regex = r'^(\d{4})'

# %%
tabla.columns 
print(tabla['Name'])
# Out:
# 0            Julie Wolfe
# 1        Adyson McNeely
# 2            John Denges
# 3                   male
# 4         Gustavo Ramos
#               ...
# 25718                NaN
# 25719                NaN
# 25720                NaN
# 25721                NaN
# 25722                NaN
# Name: Name, Length: 25723, dtype: object

# %%
tabla2 = tabla.rename(columns={'Area':'State', 
                              'Case Number':'Date Numerica', 'pdf':'Formato pdf', 'href formula':'Localizador Uniforma de Recursos','href':'URL'})

tabla2.columns
# Out:
# Index(['Date Numerica', 'Date', 'Year', 'Type', 'Country', 'State', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'Formato pdf',
#        'Localizador Uniforma de Recursos', 'URL', 'Case Number.1',
#        'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
tabla2.head()
# Out:
#   Date Numerica         Date    Year        Type    Country            State  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
# Eliminar la información innecesaria así como dichas columnas
del tabla2['Unnamed: 22']
del tabla2['Unnamed: 23']
del tabla2['URL']

# %%
tabla2.head()
# Out:
#   Date Numerica         Date    Year        Type    Country            State  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
# Llenado donde no existe información
tabla2 = tabla2.fillna('')
tabla2
# Out:
#       Date Numerica         Date  Year        Type    Country  \
# 0        2018.06.25  25-Jun-2018  2018     Boating        USA
# 1        2018.06.18  18-Jun-2018  2018  Unprovoked        USA
# 2        2018.06.09  09-Jun-2018  2018     Invalid        USA
# 3        2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA
# 4        2018.06.04  04-Jun-2018  2018    Provoked     MEXICO
# ...             ...          ...   ...         ...        ...
# 25718
# 25719
# 25720
# 25721
# 25722            xx
#
#                  State                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# ...

# %%
tabla2.columns
# Out:
# Index(['Date Numerica', 'Date', 'Year', 'Type', 'Country', 'State', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'Formato pdf',
#        'Localizador Uniforma de Recursos', 'Case Number.1', 'Case Number.2',
#        'original order'],
#       dtype='object')

# %%
# Localizar variables en la limpia de tabla2
stripped_body = (tabla2.apply(lambda row: row['Location'], axis=1))
stripped_body

tabla2.loc[tabla2['Name']== 'male']
# Out:
#      Date Numerica         Date  Year        Type             Country  \
# 3       2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 7       2018.05.27  27-May-2018  2018  Unprovoked                 USA
# 9     2018.05.26.a  26-May-2018  2018  Unprovoked                 USA
# 10      2018.05.24  24-May-2018  2018    Provoked           AUSTRALIA
# 15      2018.05.12  12-May-2018  2018  Unprovoked        SOUTH AFRICA
# ...            ...          ...   ...         ...                 ...
# 6273       ND.0030  Before 1905     0  Unprovoked               BURMA
# 6285       ND.0017  Before 1921     0  Unprovoked        SOUTH AFRICA
# 6286       ND.0016  Before 1921     0  Unprovoked        SOUTH AFRICA
# 6297       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 6301       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                       State  \
# 3           New South Wales
# 7                   Florida
# 9                   Florida
# ...

# %%
tabla2.loc[tabla2['Name'].str.contains('male', flags = re.I, regex = True)]
# Out:
#      Date Numerica                Date  Year        Type             Country  \
# 3       2018.06.08         08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 7       2018.05.27         27-May-2018  2018  Unprovoked                 USA
# 9     2018.05.26.a         26-May-2018  2018  Unprovoked                 USA
# 10      2018.05.24         24-May-2018  2018    Provoked           AUSTRALIA
# 15      2018.05.12         12-May-2018  2018  Unprovoked        SOUTH AFRICA
# ...            ...                 ...   ...         ...                 ...
# 6285       ND.0017         Before 1921     0  Unprovoked        SOUTH AFRICA
# 6286       ND.0016         Before 1921     0  Unprovoked        SOUTH AFRICA
# 6288       ND.0014  Before 17-Jul-1916     0  Unprovoked                 USA
# 6297       ND.0005         Before 1903     0  Unprovoked           AUSTRALIA
# 6301       ND.0001           1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                       State  \
# ...

# %%
def get_NON(item):
    if ' NaN' in item:
        return item[:item.find(' NaN')]
    elif ',' in item:
        return item[:item.find(',')]
    else:
        return item

# %%
tabla2['Date'].value_counts()
# Out:
#                19421
# 1957              11
# 1942               9
# 1956               8
# 1958               7
#                ...
# 06-Oct-1988        1
# 05-Jul-1883        1
# 1839/1840          1
# 10-Apr-2013        1
# 18-Nov-1964        1
# Name: Date, Length: 5434, dtype: int64

# %%
# Cambiar la palabra male por no exist de la columna nombre
tabla2.loc[tabla['Name']== 'male', ['Name']] = 'No exist'
tabla2
# Out:
#       Date Numerica         Date  Year        Type    Country  \
# 0        2018.06.25  25-Jun-2018  2018     Boating        USA
# 1        2018.06.18  18-Jun-2018  2018  Unprovoked        USA
# 2        2018.06.09  09-Jun-2018  2018     Invalid        USA
# 3        2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA
# 4        2018.06.04  04-Jun-2018  2018    Provoked     MEXICO
# ...             ...          ...   ...         ...        ...
# 25718
# 25719
# 25720
# 25721
# 25722            xx
#
#                  State                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# ...

# %%
# Cambio de int a str
tabla['Year'].astype('str')
# Out:
# 0        2018.0
# 1        2018.0
# 2        2018.0
# 3        2018.0
# 4        2018.0
#           ...
# 25718       nan
# 25719       nan
# 25720       nan
# 25721       nan
# 25722       nan
# Name: Year, Length: 25723, dtype: object

# %%
# Asignar un guion a lo que no tiene nada de informacion
tabla2.loc[tabla2['Year']== '',['Year', 'Date Numerica']] = 0
tabla2
# Out:
#       Date Numerica         Date  Year        Type    Country  \
# 0        2018.06.25  25-Jun-2018  2018     Boating        USA
# 1        2018.06.18  18-Jun-2018  2018  Unprovoked        USA
# 2        2018.06.09  09-Jun-2018  2018     Invalid        USA
# 3        2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA
# 4        2018.06.04  04-Jun-2018  2018    Provoked     MEXICO
# ...             ...          ...   ...         ...        ...
# 25718             0                  0
# 25719             0                  0
# 25720             0                  0
# 25721             0                  0
# 25722             0                  0
#
#                  State                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# ...

# %%
# Convertir a int y asignar valor a los '0'
tabla2['Year'].astype('int')
tabla2.loc[tabla2['Year'] <1000,['Year']] = 'No year info'
tabla2
# Out:
#       Date Numerica         Date          Year        Type    Country  \
# 0        2018.06.25  25-Jun-2018          2018     Boating        USA
# 1        2018.06.18  18-Jun-2018          2018  Unprovoked        USA
# 2        2018.06.09  09-Jun-2018          2018     Invalid        USA
# 3        2018.06.08  08-Jun-2018          2018  Unprovoked  AUSTRALIA
# 4        2018.06.04  04-Jun-2018          2018    Provoked     MEXICO
# ...             ...          ...           ...         ...        ...
# 25718             0               No year info
# 25719             0               No year info
# 25720             0               No year info
# 25721             0               No year info
# 25722             0               No year info
#
#                  State                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
tabla2.loc[tabla2['Age'].str.contains('[A-Z]', flags=re.I, regex = True)]
tabla2
# Out:
#       Date Numerica         Date          Year        Type    Country  \
# 0        2018.06.25  25-Jun-2018          2018     Boating        USA
# 1        2018.06.18  18-Jun-2018          2018  Unprovoked        USA
# 2        2018.06.09  09-Jun-2018          2018     Invalid        USA
# 3        2018.06.08  08-Jun-2018          2018  Unprovoked  AUSTRALIA
# 4        2018.06.04  04-Jun-2018          2018    Provoked     MEXICO
# ...             ...          ...           ...         ...        ...
# 25718             0               No year info
# 25719             0               No year info
# 25720             0               No year info
# 25721             0               No year info
# 25722             0               No year info
#
#                  State                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# tabla2['Age'].head(40)

# %%
#MODIFICANDO COLUMNA Sex

tabla2['Sex']= tabla2['Sex'].str.replace('F', 'Female')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-254-0baa807a98ca> in <module>
#       1 #MODIFICANDO COLUMNA Case number1
#       2
# ...

# %%
#Ajuste COLUMNA TIME
tabla2.loc[tabla2.Time == 'Afternoon', 'Time'] = '12:00'
tabla2.loc[tabla2.Time == '14h00-15h00', 'Time'] = '14:30'
tabla2.loc[tabla2.Time == '07h45', 'Time'] = '07:45'
tabla2.loc[tabla2.Time == 'Late afternoon', 'Time'] = '18:00'
tabla2.loc[tabla2.Time == '17h00', 'Time'] = '17:00'
tabla2.loc[tabla2.Time == '18h00', 'Time'] = '18:00'
tabla2.loc[tabla2.Time == '14h00', 'Time'] = '14:00'
tabla2.loc[tabla2.Time == 'Morning', 'Time'] = '10:00'
tabla2.loc[tabla2.Time == '15h00', 'Time'] = '15:00'
tabla2.loc[tabla2.Time == '22h00', 'Time'] = '22:00'
tabla2.loc[tabla2.Time == 'Night', 'Time'] = '20:00'

# %%
tabla2
# Out:
#       Date Numerica         Date          Year        Type    Country  \
# 0        2018.06.25  25-Jun-2018          2018     Boating        USA
# 1        2018.06.18  18-Jun-2018          2018  Unprovoked        USA
# 2        2018.06.09  09-Jun-2018          2018     Invalid        USA
# 3        2018.06.08  08-Jun-2018          2018  Unprovoked  AUSTRALIA
# 4        2018.06.04  04-Jun-2018          2018    Provoked     MEXICO
# ...             ...          ...           ...         ...        ...
# 25718             0               No year info
# 25719             0               No year info
# 25720             0               No year info
# 25721             0               No year info
# 25722             0               No year info
#
#                  State                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...
