# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
import pymongo
client= pymongo.MongoClient("mongodb://localhost:27017/")
mydb=client.db_companies
db.companies
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db_companies'), 'companies')

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
colec = db.companies
print (db.list_collection_names())
list(colec.find({'name':{'$lt':'Babelgum'}},{'name':1, '_id':0}))
# Out:
# ['companies']
# [{'name': 'AdventNet'},
#  {'name': 'AddThis'},
#  {'name': 'AdaptiveBlue'},
#  {'name': 'AllPeers'},
#  {'name': 'AllofMP3'},
#  {'name': '37signals'},
#  {'name': 'Adobe Systems'},
#  {'name': 'Amazon'},
#  {'name': 'Alstrasoft'},
#  {'name': 'AOL'},
#  {'name': 'Aniboom'},
#  {'name': 'ActiveWorlds'},
#  {'name': 'Akamai Technologies'},
#  {'name': 'A9'},
#  {'name': 'Alibaba'},
#  {'name': 'Atom Entertainment'},
#  {'name': 'Adknowledge'},
#  {'name': 'BBE'},
#  {'name': 'Alloy'},
#  {'name': 'AdMob'},
#  {'name': 'AgentMatch'},
#  {'name': 'Attributor'},
#  {'name': '4INFO'},
#  {'name': 'Aviary'},
#  {'name': 'Avvo'},
#  {'name': 'Auctomatic'},
#  {'name': 'Airborne Mobile'},
#  {'name': 'Animoto'},
#  {'name': '3Jam'},
#  {'name': '23andMe'},
#  {'name': 'AdReady'},
#  {'name': 'Automattic'},
#  {'name': 'All-Scrap'},
#  {'name': 'Alipay'},
#  {'name': 'Alisoft'},
#  {'name': 'ActionThis'},
#  {'name': 'Akimbo'},
#  {'name': 'Adteractive'},
# ...

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
list(colec.find({'number_of_employees':{'$gt':5000}},{'number_of_employees':1, '_id':0}).sort('number_of_employees',1).limit(20))
# Out:
# [{'number_of_employees': 5080},
#  {'number_of_employees': 5200},
#  {'number_of_employees': 5299},
#  {'number_of_employees': 5300},
#  {'number_of_employees': 5400},
#  {'number_of_employees': 5400},
#  {'number_of_employees': 5500},
#  {'number_of_employees': 5729},
#  {'number_of_employees': 5763},
#  {'number_of_employees': 6000},
#  {'number_of_employees': 6000},
#  {'number_of_employees': 6000},
#  {'number_of_employees': 6000},
#  {'number_of_employees': 6200},
#  {'number_of_employees': 6200},
#  {'number_of_employees': 6400},
#  {'number_of_employees': 6800},
#  {'number_of_employees': 7000},
#  {'number_of_employees': 7173},
#  {'number_of_employees': 7400}]

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
list(colec.find(
{'$and':[{'founded_year':{'$gte':2000}},{'founded_year':{'$lte':2005}}]},
{'founded_year':1,'name':1,'_id':0}))
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005},
#  {'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Digg', 'founded_year': 2004},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'Omnidrive', 'founded_year': 2005},
#  {'name': 'StumbleUpon', 'founded_year': 2002},
#  {'name': 'Gizmoz', 'founded_year': 2003},
#  {'name': 'Helio', 'founded_year': 2005},
#  {'name': 'Plaxo', 'founded_year': 2002},
#  {'name': 'Technorati', 'founded_year': 2002},
#  {'name': 'AddThis', 'founded_year': 2004},
#  {'name': 'Veoh', 'founded_year': 2004},
#  {'name': 'Jingle Networks', 'founded_year': 2005},
#  {'name': 'Meetup', 'founded_year': 2002},
#  {'name': 'LifeLock', 'founded_year': 2005},
#  {'name': 'Wesabe', 'founded_year': 2005},
#  {'name': 'Jangl SMS', 'founded_year': 2005},
#  {'name': 'SmugMug', 'founded_year': 2002},
#  {'name': 'Jajah', 'founded_year': 2005},
#  {'name': 'Skype', 'founded_year': 2003},
#  {'name': 'YouTube', 'founded_year': 2005},
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
list(colec.find(
    {'$and':[{'ipo.valuation_amount':{'$gt':100000000}},{'founded_year':{'$lte':2010}}]},
    {'ipo':1,'name':1, '_id':0}
))
# Out:
# [{'name': 'Facebook',
#   'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'name': 'Twitter',
#   'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}},
#  {'name': 'Yelp',
#   'ipo': {'valuation_amount': 1300000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 3,
#    'pub_day': 2,
#    'stock_symbol': 'NYSE:YELP'}},
#  {'name': 'LinkedIn',
#   'ipo': {'valuation_amount': 9310000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2011,
#    'pub_month': 7,
#    'pub_day': 20,
#    'stock_symbol': 'NYSE:LNKD'}},
#  {'name': 'Amazon',
#   'ipo': {'valuation_amount': 100000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 1997,
#    'pub_month': 5,
#    'pub_day': None,
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
list(colec.find(
    {'$and':[{'number_of_employees':{'$lt':1000}},
             {'founded_year':{'$lte':2005}}]},
    {'number_of_employees':-1,'founded_year':1, '_id':0}
    ).sort('number_of_employees',-1).limit(10))
# Out:
# [{'number_of_employees': 974, 'founded_year': 2000},
#  {'number_of_employees': 950, 'founded_year': 2005},
#  {'number_of_employees': 948, 'founded_year': 1997},
#  {'number_of_employees': 931, 'founded_year': 1997},
#  {'number_of_employees': 903, 'founded_year': 1983},
#  {'number_of_employees': 900, 'founded_year': 2005},
#  {'number_of_employees': 900, 'founded_year': 1991},
#  {'number_of_employees': 900, 'founded_year': 1999},
#  {'number_of_employees': 881, 'founded_year': 1999},
#  {'number_of_employees': 800, 'founded_year': 2004}]

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
list(colec.find(
{'partners':{'$exists':False}}, {'name':1,'_id':0}))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
list(colec.find(
  {'category_code':'null'}
))
# Out:
# []

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
list(colec.find(
  {'$and':[{'number_of_employees':{'$gte':100}}, {'number_of_employees':{'$lt':1000}}]},
  {'number_of_employees':1,'name':1, '_id':0}  
    
).sort('number_of_employees',1))
# Out:
# [{'name': 'Redfin', 'number_of_employees': 100},
#  {'name': 'Simply Hired', 'number_of_employees': 100},
#  {'name': 'hi5', 'number_of_employees': 100},
#  {'name': 'INgage Networks', 'number_of_employees': 100},
#  {'name': 'mig33', 'number_of_employees': 100},
#  {'name': 'Fon', 'number_of_employees': 100},
#  {'name': 'EchoSign', 'number_of_employees': 100},
#  {'name': 'TrialPay', 'number_of_employees': 100},
#  {'name': 'Firetide', 'number_of_employees': 100},
#  {'name': 'Verimatrix', 'number_of_employees': 100},
#  {'name': 'Blyk', 'number_of_employees': 100},
#  {'name': 'Survey Analytics', 'number_of_employees': 100},
#  {'name': 'Social Gaming Network', 'number_of_employees': 100},
#  {'name': 'Covario', 'number_of_employees': 100},
#  {'name': '99designs', 'number_of_employees': 100},
#  {'name': 'Elance', 'number_of_employees': 100},
#  {'name': 'Vovici', 'number_of_employees': 100},
#  {'name': '2ergo', 'number_of_employees': 100},
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
 list(colec.find(
     {'ipo.valuation_amount':{'$exists':True}},{'ipo':1,'_id':0}).sort('ipo.valuation_amount',-1))
# Out:
# [{'ipo': {'valuation_amount': 108960000000,
#    'valuation_currency_code': 'JPY',
#    'pub_year': 2008,
#    'pub_month': 12,
#    'pub_day': 17,
#    'stock_symbol': '3632'}},
#  {'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'ipo': {'valuation_amount': 100000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 1997,
#    'pub_month': 5,
#    'pub_day': None,
#    'stock_symbol': 'NASDAQ:AMZN'}},
#  {'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}},
#  {'ipo': {'valuation_amount': 12800000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2011,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NASDAQ:GRPN'}},
#  {'ipo': {'valuation_amount': 11000000000,
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
 list(colec.find(
     {'number_of_employees':{'$gt':0}},
     {'number_of_employees':1,'_id':0,'name':1}).sort('number_of_employees',-1).limit(10))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'Toyota', 'number_of_employees': 320000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Tata Consultancy Services', 'number_of_employees': 200300},
#  {'name': 'Flextronics International', 'number_of_employees': 200000},
#  {'name': 'Safeway', 'number_of_employees': 186000}]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
list(colec.find(
    {'founded_month':{'$gt':6}},{'founded_month':1, 'name':1, '_id':0})

.sort('founded_month',1).limit(1000))
# Out:
# [{'name': 'Pando Networks', 'founded_month': 7},
#  {'name': 'iContact', 'founded_month': 7},
#  {'name': 'MeeVee', 'founded_month': 7},
#  {'name': 'Yelp', 'founded_month': 7},
#  {'name': 'Jaiku', 'founded_month': 7},
#  {'name': 'Yapta', 'founded_month': 7},
#  {'name': 'Terabitz', 'founded_month': 7},
#  {'name': 'GigaOM', 'founded_month': 7},
#  {'name': 'Ujogo', 'founded_month': 7},
#  {'name': 'Cyworld', 'founded_month': 7},
#  {'name': 'Cerado', 'founded_month': 7},
#  {'name': 'JumpBox', 'founded_month': 7},
#  {'name': 'LongJump', 'founded_month': 7},
#  {'name': 'Relationals', 'founded_month': 7},
#  {'name': 'Boonex', 'founded_month': 7},
#  {'name': 'Rebtel', 'founded_month': 7},
#  {'name': 'Buxfer', 'founded_month': 7},
#  {'name': 'boo-box', 'founded_month': 7},
#  {'name': 'Nirvanix', 'founded_month': 7},
#  {'name': 'Metacafe', 'founded_month': 7},
#  {'name': 'Sportingo', 'founded_month': 7},
#  {'name': 'InviteShare', 'founded_month': 7},
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %%
list(colec.find(
    {'deadpooled_year':{'$gt':3}},{'deadpooled_year':1, '_id':0,'name':1}
).sort('deadpooled_year',1))
# Out:
# [{'name': 'Weblogs', 'deadpooled_year': 1963},
#  {'name': 'Bookrags', 'deadpooled_year': 1991},
#  {'name': 'adBrite', 'deadpooled_year': 2001},
#  {'name': 'Excite@Home', 'deadpooled_year': 2001},
#  {'name': 'Ardesic', 'deadpooled_year': 2001},
#  {'name': 'sportgate AG', 'deadpooled_year': 2001},
#  {'name': 'Webvan', 'deadpooled_year': 2001},
#  {'name': 'RealNames', 'deadpooled_year': 2002},
#  {'name': 'SpongeFish', 'deadpooled_year': 2003},
#  {'name': 'MediaRush', 'deadpooled_year': 2004},
#  {'name': 'Zooomr', 'deadpooled_year': 2006},
#  {'name': 'Zoji', 'deadpooled_year': 2006},
#  {'name': 'TrueSpan', 'deadpooled_year': 2006},
#  {'name': 'AllofMP3', 'deadpooled_year': 2007},
#  {'name': 'Edgeio', 'deadpooled_year': 2007},
#  {'name': 'SlapVid', 'deadpooled_year': 2007},
#  {'name': 'FilmLoop', 'deadpooled_year': 2007},
#  {'name': 'ProQuo', 'deadpooled_year': 2007},
#  {'name': 'ScribeStorm', 'deadpooled_year': 2007},
#  {'name': 'Wakozi', 'deadpooled_year': 2007},
# ...

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
list(colec.find(
    {'$and':[{'acquisition.price_amount':{'$gt':10000000}},{'founded_year':{'$lt':2000}}]},
    {'acquisition.price_amount':1,'name':1,'_id':0}

).sort('acquisition.price_amount',1))
# Out:
# [{'name': 'Easyspace', 'acquisition': {'price_amount': 10500000}},
#  {'name': 'MIVA', 'acquisition': {'price_amount': 11600000}},
#  {'name': 'Litmus Media', 'acquisition': {'price_amount': 13000000}},
#  {'name': 'Litmus Media', 'acquisition': {'price_amount': 13000000}},
#  {'name': 'Connect3 Systems', 'acquisition': {'price_amount': 13450000}},
#  {'name': 'Iron Solutions', 'acquisition': {'price_amount': 15000000}},
#  {'name': 'Contemporary Computer Services',
#   'acquisition': {'price_amount': 15040000}},
#  {'name': 'Bookrags', 'acquisition': {'price_amount': 18000000}},
#  {'name': 'Kaboose', 'acquisition': {'price_amount': 18400000}},
#  {'name': 'Advanced Control Components',
#   'acquisition': {'price_amount': 18780000}},
#  {'name': 'Air2Web', 'acquisition': {'price_amount': 19000000}},
#  {'name': 'QuickArrow', 'acquisition': {'price_amount': 19400000}},
#  {'name': 'NextBus', 'acquisition': {'price_amount': 20600000}},
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
list(colec.find(
    {'acquisitions.acquired_year':{'$gt':2015}},{'name':1,'acquisitions.acquired_year':1,'_id':0}

).sort('acquisitions.price_amount',-1))
# Out:
# []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(colec.find({'founded_year':{'$exists':True}}, {'founded_year':1, 'name':1, '_id':0}).sort('founded_year',-1).limit(10))
# Out:
# [{'name': 'Fixya', 'founded_year': 2013},
#  {'name': 'Wamba', 'founded_year': 2013},
#  {'name': 'Advaliant', 'founded_year': 2013},
#  {'name': 'Fluc', 'founded_year': 2013},
#  {'name': 'iBazar', 'founded_year': 2013},
#  {'name': 'Gimigo', 'founded_year': 2013},
#  {'name': 'SEOGroup', 'founded_year': 2013},
#  {'name': 'Clowdy', 'founded_year': 2013},
#  {'name': 'WhosCall', 'founded_year': 2013},
#  {'name': 'Pikk', 'founded_year': 2013}]

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
list(colec.find({'founded_day':{'$lte':7}},{'name':1,'acquisition.price_amount':1, '_id':0}).sort('acquisition.price_amount',-1)

)
# Out:
# [{'name': 'Netscape', 'acquisition': {'price_amount': 4200000000}},
#  {'name': 'PayPal', 'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Zappos', 'acquisition': {'price_amount': 1200000000}},
#  {'name': 'Alibaba', 'acquisition': {'price_amount': 1000000000}},
#  {'name': 'Postini', 'acquisition': {'price_amount': 625000000}},
#  {'name': 'Danger', 'acquisition': {'price_amount': 500000000}},
#  {'name': 'Clearwell Systems', 'acquisition': {'price_amount': 410000000}},
#  {'name': 'PrimeSense', 'acquisition': {'price_amount': 345000000}},
#  {'name': 'Amobee', 'acquisition': {'price_amount': 321000000}},
#  {'name': 'BlueLithium', 'acquisition': {'price_amount': 300000000}},
#  {'name': 'Vitrue', 'acquisition': {'price_amount': 300000000}},
#  {'name': 'Alexa', 'acquisition': {'price_amount': 250000000}},
#  {'name': 'Jajah', 'acquisition': {'price_amount': 207000000}},
#  {'name': 'PlaySpan', 'acquisition': {'price_amount': 190000000}},
# ...

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
list(colec.find(
    {'$and':[{'number_of_employees':{'$gt':4000}},{'category_code':'web'}]},
    {'number_of_employees': 1, '_id':0}

).sort('number_of_employees',1))
# Out:
# [{'number_of_employees': 4400},
#  {'number_of_employees': 8000},
#  {'number_of_employees': 8657},
#  {'number_of_employees': 10000},
#  {'number_of_employees': 10000},
#  {'number_of_employees': 10000},
#  {'number_of_employees': 13600},
#  {'number_of_employees': 15000},
#  {'number_of_employees': 15500}]

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
list(colec.find(
    {'$and':[{'acquisition.price_amount':{'$gte':10000000}},{'acquisition.price_currency_code':'EUR'}]},
    {'acquisition.price_currency_code':1,'_id':0,'acquisition.price_amount':1}

).sort('acquisition.price_amount',1))
# Out:
# [{'acquisition': {'price_amount': 24000000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 31500000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 40000000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 43400000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 140000000, 'price_currency_code': 'EUR'}}]

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(colec.find(
    {'acquisition.adquired_month':{'$lt':5}},{'name':1,'acquisition.acquired_month':1, '_id':0}

).limit(10))
# Out:
# []

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
list(colec.find(
    {'$and':[{'acquisition.acquired_year':{'$gte':2011}},
    {'founded_year':{'$gte':2000}},{'founded_year':{'$lte':2010}}]},
    {'acquisition.acquired_year':1,'founded_year':1,'_id':0}

).sort('acquisition.acquired_year',1))
# Out:
# [{'founded_year': 2006, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2005, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2003, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2005, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2004, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2005, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2006, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2004, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2003, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2005, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2005, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2001, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2003, 'acquisition': {'acquired_year': 2011}},
#  {'founded_year': 2005, 'acquisition': {'acquired_year': 2011}},
# ...
